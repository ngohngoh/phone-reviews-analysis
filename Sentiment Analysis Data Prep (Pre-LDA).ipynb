# %%
import pandas as pd
import nltk
import re
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords
from nltk.stem.porter import *

# %%
df = pd.read_csv("cleaned_phone_data_excl_extracts_clean.csv")

# %%
df.head()
# Out:
#         date lang country            source               domain  score  \
# 0   5/2/2017   en      us  Verizon Wireless  verizonwireless.com   10.0
# 1  4/28/2017   en      us       Phone Arena       phonearena.com   10.0
# 2   5/4/2017   en      us            Amazon           amazon.com    6.0
# 3   5/2/2017   en      us           Samsung          samsung.com    9.2
# 4  5/11/2017   en      us  Verizon Wireless  verizonwireless.com    4.0
#
#    score_max                                            extract       author  \
# 0       10.0  As a diehard Samsung fan who has had every Sam...   CarolAnn35
# 1       10.0  Love the phone. the phone is sleek and smooth ...    james0923
# 2       10.0  Adequate feel. Nice heft. Processor's still sl...     R. Craig
# 3       10.0  Never disappointed. One of the reasons I've be...  Buster2020
# 4       10.0  I've now found that i'm in a group of people t...   S Ate Mine
#
# ...

# %%
#After cleaning the reviews (extract), we will store it into a new df - 'cleaned_extracts_df'
# Test with three row df

#df_test = df.iloc[:3]

stop_list = stopwords.words('english')
extracts_list = df.loc[:,'extract'].tolist()
cleaned_extracts_list = []
for extracts in extracts_list:
    #lowercase
    extracts_lower = extracts.lower()
    #Do all the other text cleaning here

    '''Remember to append the final cleaned extract to cleaned_extracts_list below by 
    uncommenting and changing extracts_lower to whatever variable name u use'''
    #cleaned_extracts_list.append(extracts_lower)

    
'''Once all that is done, drop the original extracts column and reinsert a new one by uncommenting the stuff below'''
#cleaned_extracts_df = df
#cleaned_extracts_df.drop(['extract'], axis=1, inplace = True)
#cleaned_extracts_df.insert(7, 'extract', cleaned_extracts_list)

# %%
#cleaned_extracts_df.head()
# Out:
#         date lang country            source               domain  score  \
# 0   5/2/2017   en      us  Verizon Wireless  verizonwireless.com   10.0
# 1  4/28/2017   en      us       Phone Arena       phonearena.com   10.0
# 2   5/4/2017   en      us            Amazon           amazon.com    6.0
# 3   5/2/2017   en      us           Samsung          samsung.com    9.2
# 4  5/11/2017   en      us  Verizon Wireless  verizonwireless.com    4.0
#
#    score_max                                            extract       author  \
# 0       10.0  as a diehard samsung fan who has had every sam...   CarolAnn35
# 1       10.0  love the phone. the phone is sleek and smooth ...    james0923
# 2       10.0  adequate feel. nice heft. processor's still sl...     R. Craig
# 3       10.0  never disappointed. one of the reasons i've be...  Buster2020
# 4       10.0  i've now found that i'm in a group of people t...   S Ate Mine
#
# ...
